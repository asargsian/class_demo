# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'MyDrive/Econ_demo/demo' 
# replace with your Github username 
GIT_USERNAME = "asargsian" 
# definitely replace with your
GIT_TOKEN = "651dc4125a8e12178a0d163919db2d5ce4b7448f"  
# Replace with your github repository in this case we want 
# to clone  repository
GIT_REPOSITORY = "class_demo" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/Econ_demo/demo
# mkdir: cannot create directory ‘/content/drive/MyDrive/Econ_demo/demo’: File exists
# GIT_PATH:  https://651dc4125a8e12178a0d163919db2d5ce4b7448f@github.com/asargsian/class_demo.git

# %%
# %cd "{PROJECT_PATH}" + "/" + "{GIT_REPOSITORY}"
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Econ_demo/demo + / + class_demo'
# /content/drive/MyDrive/Econ_demo/demo

# %%
"{PROJECT_PATH}" + "/" + "{GIT_REPOSITORY}"
# Out:
# '{PROJECT_PATH}/{GIT_REPOSITORY}'

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
